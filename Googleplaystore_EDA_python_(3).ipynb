# %% [markdown]
# <a href="https://colab.research.google.com/github/RittikaNanwani/Python-based-EDA-for-Google-Play-Store-Analysis/blob/main/Googleplaystore_EDA_python_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 2. loading dataset into DataFrame

# %%
df = pd.read_csv("Google-Playstore.csv")

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
#no. of rows and columns
df.shape
# Out:
# (2312944, 24)

# %%
# provides concise summary of a DataFrame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312944 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# dtypes: bool(4), float64(4), int64(1), object(15)
# memory usage: 361.8+ MB

# %%
#descriptive statistics of a DataFrame.
df.describe()
# Out:
#              Rating  Rating Count  Minimum Installs  Maximum Installs  \
# count  2.290061e+06  2.290061e+06      2.312837e+06      2.312944e+06
# mean   2.203152e+00  2.864839e+03      1.834452e+05      3.202017e+05
# std    2.106223e+00  2.121626e+05      1.513144e+07      2.355495e+07
# min    0.000000e+00  0.000000e+00      0.000000e+00      0.000000e+00
# 25%    0.000000e+00  0.000000e+00      5.000000e+01      8.400000e+01
# 50%    2.900000e+00  6.000000e+00      5.000000e+02      6.950000e+02
# 75%    4.300000e+00  4.200000e+01      5.000000e+03      7.354000e+03
# max    5.000000e+00  1.385576e+08      1.000000e+10      1.205763e+10
#
#               Price
# count  2.312944e+06
# mean   1.034992e-01
# std    2.633127e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    4.000000e+02

# %%
#used to display maximum number of columns
pd.set_option('display.max_columns',None)

# %%
total_distinct_apps = df['App Name'].nunique()
print(total_distinct_apps)
# Out:
# 2177944

# %%
df.head(50)
# Out:
#                                              App Name  \
# 0                                             Gakondo
# 1                                 Ampere Battery Info
# 2                                              Vibook
# 3   Smart City Trichy Public Service Vehicles 17UC...
# 4                                             GROW.me
# 5                                              IMOCCI
# 6                    unlimited 4G data prank free app
# 7                               The Everyday Calendar
# 8                                           WhatsOpen
# 9                    Neon 3d Iron Tech Keyboard Theme
# 10                                    Dodge The Cars!
# 11                                            Parents
# 12                     桃園機場捷運時刻表 - 捷運轉乘路線快速查詢(支援台北捷運)
# 13                                       be.MOBILISED
# 14                                  Caliway Conductor
# 15                              Readymade Grocery App
# 16                               OTENTIK Discovery FR
# 17                            All in one shopping app
# 18                                     REDMOND  Robot
# 19                     Contemporary Love Wallpaper HD
# 20                                    Nepali Congress
# 21                                  Bhavan's BHEL VIM
# 22                            Block Fill: Puzzle Game
# 23                              Coloring Book Barbaie
# 24                            Random Number Generator
# 25                                        Sticky Ball
# 26                                       CUBIC RUNNER
# 27                Dj Car Sound And Sound Effects 2019
# 28                                         Schoolbus*
# 29                                  Cambodian.Express
# 30                                       Barnets Hair
# 31                                            GaiaZOO
# 32       Photo Brightness Editor - Image Brighten App
# 33                                       Creepy Story
# 34                              Vancouver Bus Tracker
# 35                                 Serbia Audio Guide
# 36                                    Head Lice guide
# 37                  Calculus Tutorial 1: Introduction
# 38                             Business Class Fitness
# 39     Sudan Flag Wallpaper: Flags, Country HD Images
# 40                                          BuradaOto
# 41                                       MoveNow User
# 42                           Niagara Falls Wallpapers
# 43                                    Extrude Balance
# 44                                    1-Click Hotspot
# 45                            Psychrometry Calculator
# 46                                    Bounce & Bubble
# 47                                       Radio Louvor
# 48                        Peribahasa Bahasa Indonesia
# 49                          Bowling Paradise Pro FREE
#
#                                                App Id           Category  \
# 0                                 com.ishakwe.gakondo          Adventure
# 1                          com.webserveis.batteryinfo              Tools
# 2                                com.doantiepvien.crm       Productivity
# 3                             cst.stJoseph.ug17ucs548      Communication
# 4                                com.horodyski.grower              Tools
# 5                                          com.imocci             Social
# 6       getfreedata.superfatiza.unlimitedjiodataprank   Libraries & Demo
# 7                              com.mozaix.simoneboard          Lifestyle
# 8                                   com.whatsopen.app      Communication
# 9               com.ikeyboard.theme.neon_3d.iron.tech    Personalization
# 10               com.MrScratchEnterprises.CarDogeGame             Racing
# 11                       com.eqra.android.BSTS.parent  Maps & Navigation
# 12                            com.jieapp.taoyuanmetro     Travel & Local
# 13                            com.hastobe.bemobilised  Maps & Navigation
# 14                        com.caliwayconductor.driver     Travel & Local
# 15       com.ionicfirebaseapp.readymadegroceryuserapp       Food & Drink
# 16                   com.camineo.otentikdiscoveryDLFR     Travel & Local
# 17             com.tkapplications.allinoneshoppingapp              Tools
# 18                                   com.grit.redmond          Lifestyle
# 19                           com.felingdev.lowalpaper  Books & Reference
# 20                              np.com.NepaliCongress             Social
# 21                                    com.bhavans.vim            Medical
# 22  com.mailbeegames.casual.brain.line.block.puzzl...             Puzzle
# 23                                com.bisgumah.barbie      Entertainment
# 24                              com.gary.randomnumber              Tools
# 25                 com.mitochondriastudios.stickyball             Arcade
# 26                         jp.ga_software.cubicrunner             Arcade
# 27                      com.melonappsvpn.dj_carsounds      Entertainment
# 28                            com.forumloft.schoolbus  Maps & Navigation
# 29                                 com.cambodia.ceapp    Auto & Vehicles
# 30                            com.phorest.barnetshair          Lifestyle
# 31                            nl.haveaniceday.gaiazoo     Travel & Local
# 32                      image.photo.brightness.editor        Photography
# 33                               com.creepypasta.club      Entertainment
# 34                         beyond.translinkbustracker  Maps & Navigation
# 35                                   apetra.tourguide     Travel & Local
# 36                    com.andromo.dev667101.app672597   Health & Fitness
# 37                         com.RaySemiSoft.CalculusT1          Education
# 38                com.bhappdevelopment.samuelvankuren   Health & Fitness
# 39                     com.techzit.sudanflagwallpaper    Personalization
# 40                             com.rzmobile.buradaoto           Shopping
# 41                                com.movenowcustomer     Travel & Local
# 42            com.niagara.wallpapers.backgrounds_0001    Personalization
# 43                  com.creatorsbureau.extrudebalance             Arcade
# 44                  com.one.click.wifi.tethering.free              Tools
# 45                        com.s3software.psychrometry              Tools
# 46                              com.game.bouncebubble              Board
# 47                               hoostcomv2.francisco      Music & Audio
# 48                    com.andromo.dev298605.app412818  Books & Reference
# 49                 com.innolab.BowlingParadiseProFREE             Sports
#
#     Rating  Rating Count  Installs  Minimum Installs  Maximum Installs  Free  \
# 0      0.0           0.0       10+              10.0                15  True
# 1      4.4          64.0    5,000+            5000.0              7662  True
# 2      0.0           0.0       50+              50.0                58  True
# 3      5.0           5.0       10+              10.0                19  True
# 4      0.0           0.0      100+             100.0               478  True
# 5      0.0           0.0       50+              50.0                89  True
# 6      4.5          12.0    1,000+            1000.0              2567  True
# 7      2.0          39.0      500+             500.0               702  True
# 8      0.0           0.0       10+              10.0                18  True
# 9      4.7         820.0   50,000+           50000.0             62433  True
# 10     4.9          55.0      100+             100.0               329  True
# 11     0.0           0.0      100+             100.0               330  True
# 12     3.9         118.0   10,000+           10000.0             37763  True
# 13     0.0           0.0      100+             100.0               274  True
# 14     3.7        1572.0   10,000+           10000.0             42856  True
# 15     4.2          16.0    1,000+            1000.0              4313  True
# 16     3.4           5.0      500+             500.0               949  True
# 17     5.0           6.0       50+              50.0                62  True
# 18     3.7         328.0   10,000+           10000.0             31235  True
# 19     0.0           0.0        1+               1.0                 2  True
# 20     0.0           0.0      100+             100.0               336  True
# 21     0.0           0.0       10+              10.0                31  True
# 22     4.4         211.0   10,000+           10000.0             15471  True
# 23     3.8         736.0  500,000+          500000.0            646456  True
# 24     4.2          35.0   10,000+           10000.0             21124  True
# 25     4.6          11.0      100+             100.0               152  True
# 26     0.0           0.0    1,000+            1000.0              1068  True
# 27     0.0           0.0      100+             100.0               396  True
# 28     4.1          27.0    1,000+            1000.0              2414  True
# 29     3.4          16.0    1,000+            1000.0              3784  True
# 30     0.0           0.0      100+             100.0               345  True
# 31     3.4          67.0   10,000+           10000.0             30921  True
# 32     2.5          21.0    5,000+            5000.0              8984  True
# 33     0.0           0.0       10+              10.0                22  True
# 34     2.3         420.0   50,000+           50000.0             74510  True
# 35     3.7         143.0   10,000+           10000.0             43422  True
# 36     2.1          33.0   10,000+           10000.0             19889  True
# 37     0.0           0.0      100+             100.0               277  True
# 38     0.0           0.0        1+               1.0                 2  True
# 39     0.0           0.0      100+             100.0               468  True
# 40     4.9         102.0    1,000+            1000.0              4103  True
# 41     0.0           0.0        1+               1.0                 2  True
# 42     5.0          11.0      500+             500.0               825  True
# 43     5.0           8.0    1,000+            1000.0              3427  True
# 44     2.7         420.0   50,000+           50000.0             59427  True
# 45     4.3          20.0    1,000+            1000.0              1396  True
# 46     0.0           0.0       10+              10.0                37  True
# 47     0.0           0.0      100+             100.0               229  True
# 48     3.8          13.0    1,000+            1000.0              1079  True
# 49     4.4        2781.0  100,000+          100000.0            340980  True
#
#     Price Currency  Size Minimum Android                         Developer Id  \
# 0     0.0      USD   10M      7.1 and up    Jean Confident Irénée NIYIZIBYOSE
# 1     0.0      USD  2.9M      5.0 and up                           Webserveis
# 2     0.0      USD  3.7M    4.0.3 and up                           Cabin Crew
# 3     0.0      USD  1.8M    4.0.3 and up                  Climate Smart Tech2
# 4     0.0      USD  6.2M      4.1 and up                Rafal Milek-Horodyski
# 5     0.0      USD   46M      6.0 and up                          Imocci GmbH
# 6     0.0      USD  2.5M      4.1 and up                 android developer779
# 7     0.0      USD   16M      5.0 and up                           Mozaix LLC
# 8     0.0      USD  1.3M      4.4 and up               Yilver Molina Hurtatiz
# 9     0.0      USD  3.5M      4.1 and up  Free 2021 Themes for Emoji keyboard
# 10    0.0      USD   51M      4.4 and up                            MrScratch
# 11    0.0      USD  2.7M      4.0 and up                            Eqra Tech
# 12    0.0      USD  7.6M      4.2 and up                              Jie App
# 13    0.0      USD   15M      6.0 and up                       has.to.be gmbh
# 14    0.0      USD   29M      4.2 and up                              WayCali
# 15    0.0      USD   12M      4.4 and up                      pietechsolution
# 16    0.0      USD  2.9M      4.4 and up                      Hotels Attitude
# 17    0.0      USD  2.0M      4.1 and up                      TK Applications
# 18    0.0      USD   70M      4.1 and up                      Grit Technology
# 19    0.0      XXX   11M      4.2 and up                     Human Droid Apps
# 20    0.0      USD   24M      5.0 and up               Nitya Shree Developers
# 21    0.0      USD  1.4M    4.0.3 and up             Bhavans, BHEL, Hyderabad
# 22    0.0      USD   16M      5.0 and up                        MailBee Games
# 23    0.0      USD   20M      5.0 and up                             bisgumah
# 24    0.0      USD  2.4M      5.0 and up                           GaryG Apps
# 25    0.0      USD   25M      4.1 and up                 Mitochondria Studios
# 26    0.0      USD   16M      4.0 and up                          GA software
# 27    0.0      USD   21M    4.0.3 and up                        TenSept Tools
# 28    0.0      USD   11M      2.1 and up                            Forumloft
# 29    0.0      USD  6.2M      4.1 and up                             CCIT.TMS
# 30    0.0      USD   36M      5.0 and up                              Phorest
# 31    0.0      USD  7.6M      4.4 and up                          Myler Media
# 32    0.0      XXX  6.2M      4.4 and up                           Anuoluwapo
# 33    0.0      USD  6.1M      4.1 and up               AL Hidayah Corporation
# 34    0.0      USD  2.6M      4.0 and up                           Beyond 2.0
# 35    0.0      USD   11M      4.1 and up                           NTO Serbia
# 36    0.0      USD  3.7M      4.1 and up               Free Apps For Everyone
# 37    0.0      USD   15M      4.1 and up                          RaySemiSoft
# 38    0.0      USD   10M      7.0 and up               BH App Development Ltd
# 39    0.0      USD  8.9M      5.0 and up                               TZLabs
# 40    0.0      USD  3.9M    4.0.3 and up                            Buradaoto
# 41    0.0      USD   30M      4.1 and up                           MoveNowApp
# 42    0.0      USD   21M      4.1 and up                          Legend APPS
# 43    0.0      USD   26M      5.0 and up                      Creators Bureau
# 44    0.0      USD  4.9M      4.1 and up                       Limonland Apps
# 45    0.0      USD  4.3M    4.0.3 and up                             MEPPEDIA
# 46    0.0      USD  4.8M      2.2 and up                  Kossta Tech Systems
# 47    0.0      USD  4.6M      5.0 and up                                Hoost
# 48    0.0      USD  2.8M      4.1 and up                        Irwana Studio
# 49    0.0      USD   38M      2.1 and up                              InnoLab
#
#                                     Developer Website  \
# 0                         https://beniyizibyose.tk/#/
# 1                     https://webserveis.netlify.app/
# 32          True             False           False  2021-06-15 20:19:37
# 33          True             False           False  2021-06-15 20:19:37
# 34          True             False           False  2021-06-15 20:19:37
# 35         False             False           False  2021-06-15 20:19:37
# 36          True             False           False  2021-06-15 20:19:37
# 37         False             False           False  2021-06-15 20:19:37
# 38         False             False           False  2021-06-15 20:19:37
# 39          True             False           False  2021-06-15 20:19:37
# 40         False             False           False  2021-06-15 20:19:37
# 41         False             False           False  2021-06-15 20:19:37
# 42          True             False           False  2021-06-15 20:19:37
# 43          True              True           False  2021-06-15 20:19:37
# 44          True             False           False  2021-06-15 20:19:37
# 45          True             False           False  2021-06-15 20:19:38
# 46          True             False           False  2021-06-15 20:19:38
# 47         False             False           False  2021-06-15 20:19:38
# 48          True             False           False  2021-06-15 20:19:38
# 49          True              True           False  2021-06-15 20:19:38

# %% [markdown]
# #Observation: There are total 2312944 rows, also Total distinct Apps present are 2177944, total of maximum installations is 12,057,630,000 and highest rating reached is 5 means there is  presence of highly rated apps.

# %% [markdown]
# # 3.Exploratory Analysis and Visualizations

# %% [markdown]
# (1) Analyse Missing data, Visualize the Missing values and Plot Missing values in percentage:

# %%
#Checking if any null values present and sorting in ascending
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer Website    760835
# Privacy Policy       420953
# Released              71053
# Rating                22883
# Rating Count          22883
# Minimum Android        6530
# Size                    196
# Currency                135
# Installs                107
# Minimum Installs        107
# Developer Id             33
# Developer Email          31
# App Name                  2
# App Id                    0
# Price                     0
# Free                      0
# Maximum Installs          0
# Last Updated              0
# Content Rating            0
# Category                  0
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# dtype: int64

# %%
#missing values visualization
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(df.isnull(), cmap='viridis', cbar=False)
plt.title("Missing Values Heatmap", fontsize=16)
plt.xlabel("Columns", fontsize=12)
plt.ylabel("Rows", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Calculate the missing percentage of null values
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_percentage = missing_percentage[missing_percentage != 0]

# Set the figure size
plt.figure(figsize=(12, 8))

# Sort the missing percentage in ascending order
missing_percentage = missing_percentage.sort_values()

# Plotting the missing percentage
ax = missing_percentage.plot(kind='barh', color='red')
plt.title("Missing Percentage of Null Values", fontsize=20)
plt.xlabel("Percentage", fontsize=14)
plt.ylabel("Columns", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add data labels to the bars
for i, v in enumerate(missing_percentage):
    ax.text(v + 0.5, i, f"{v:.2f}%", color='black', fontsize=12, ha='left', va='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# Observation: Developer website & privacy policy column has the highest number of null values.Columns with a high missing percentage may require imputation techniques or careful consideration before using them in analysis.

# %% [markdown]
# # (3) Dropping the null values:

# %%
df = df.dropna(subset=['App Name', 'Size', 'Currency', 'Installs', 'Minimum Installs', 'Developer Id', 'Developer Email'])
df.isnull().sum()
# Out:
# App Name                  0
# App Id                    0
# Category                  0
# Rating                22572
# Rating Count          22572
# Installs                  0
# Minimum Installs          0
# Maximum Installs          0
# Free                      0
# Price                     0
# Currency                  0
# Size                      0
# Minimum Android        6530
# Developer Id              0
# Developer Website    760716
# Developer Email           0
# Released              70748
# Last Updated              0
# Content Rating            0
# Privacy Policy       420845
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# dtype: int64

# %% [markdown]
# # (4) Checking for Duplicates:

# %%
#checking any duplicates in App name
boolean = df['App Name'].duplicated().any()
boolean
# Out:
# True

# %%
df['App Name'].value_counts()
# Out:
# Tic Tac Toe                     382
# Calculator                      261
# Flashlight                      256
# BMI Calculator                  201
# Age Calculator                  190
#                                ...
# Foodiz Resto                      1
# Astra OtoReward                   1
# MedTerm Dictionary                1
# Urban garden and sowing.          1
# Biliyor Musun - Sonsuz Yarış      1
# Name: App Name, Length: 2177593, dtype: int64

# %%
#Lets check whether data in app name row is identical or not
df[df['App Name']=='Tic Tac Toe']
# Out:
#             App Name                             App Id Category  Rating  \
# 3918     Tic Tac Toe           com.dev.atte.tic_tac_toe   Puzzle     0.0
# 13758    Tic Tac Toe                   com.md.tictactoe    Board     0.0
# 25351    Tic Tac Toe        com.sthirumuru.tictactoenew    Board     4.2
# 28142    Tic Tac Toe               com.fsk00x.TicTacToe    Board     0.0
# 30962    Tic Tac Toe         net.snatchdreams.tictactoe   Puzzle     0.0
# ...              ...                                ...      ...     ...
# 2272773  Tic Tac Toe        com.tictactoe.MobileAppsPro    Board     3.8
# 2281376  Tic Tac Toe     com.erjainam.tictactoe.release    Board     0.0
# 2282023  Tic Tac Toe          com.swapworld.tic_tac_toe    Board     4.7
# 2299121  Tic Tac Toe               com.infuse.tictactoe    Board     4.8
# 2310375  Tic Tac Toe  com.justmailtoavi.avinashk.threet   Puzzle     4.7
#
#          Rating Count  Installs  Minimum Installs  Maximum Installs  Free  \
# 3918              0.0       10+              10.0                30  True
# 13758             0.0       10+              10.0                31  True
# 25351            11.0    5,000+            5000.0              6379  True
# 28142             0.0      500+             500.0               922  True
# 30962             0.0       10+              10.0                38  True
# ...               ...       ...               ...               ...   ...
# 2272773        9269.0  500,000+          500000.0            800662  True
# 2281376           0.0       50+              50.0                50  True
# 2282023           7.0       10+              10.0                34  True
# 2299121          20.0      100+             100.0               462  True
# 2310375          10.0      100+             100.0               173  True
#
#          Price Currency  Size Minimum Android             Developer Id  \
# 3918       0.0      USD  3.4M      4.0 and up        ATTE AKA FRANCOIS
# 13758      0.0      USD   34M      4.3 and up      Smart Digital Tools
# 25351      0.0      USD  7.4M      7.0 and up  Sundeep Reddy Thirumuru
# 28142      0.0      USD  8.6M      4.1 and up          SteadFast Games
# 30962      0.0      USD  927k      4.0 and up             SnatchDreams
# ...        ...      ...   ...             ...                      ...
# 2272773    0.0      USD  2.3M      2.3 and up          Mobile Apps Pro
# 2281376    0.0      USD  3.5M      5.0 and up           Jainam Jhaveri
# 2282023    0.0      USD  5.3M      4.1 and up     Cybertron's Hogwarts
# 2299121    0.0      USD  2.1M      2.2 and up              Infuse Apps
# 2310375    0.0      USD  1.7M      4.4 and up               RentMyTent
#
#                                       Developer Website  \
# 3918                  https://ne2ad32ee.app-ads-txt.com
# 13758                                               NaN
# 25351                                               NaN
# 28142                                               NaN
# 30962                      https://www.snatchdreams.net
# ...                                                 ...
# 2272773                                             NaN
# 2281376                            https://erjainam.com
# 2282023  http://prudhvikchirunomula.pythonanywhere.com/
# 2299121                       http://www.infuseapps.com
# 2310375                                             NaN
#
#                      Developer Email      Released  Last Updated  \
# 3918     dev.atte.francois@gmail.com  May 18, 2018  May 18, 2018
# 13758           msms.zaman@gmail.com   Nov 2, 2020  Nov 18, 2020
# 25351    sundeep.thirumuru@gmail.com  Apr 13, 2021  Jun 03, 2021
# 28142          devmethyl@outlook.com  Feb 13, 2020  Feb 13, 2020
# 30962         snatchdreams@gmail.com  Jul 16, 2017  Oct 16, 2019
# ...                              ...           ...           ...
# 2272773           smartyka@gmail.com   Jan 9, 2015  May 20, 2015
# 2281376     engineerjainam@gmail.com   Sep 2, 2018  Sep 02, 2018
# 2282023      prudhvik.1996@gmail.com   Sep 4, 2019  Sep 17, 2019
# 2299121  infuseandroidapps@gmail.com  Jan 18, 2015  Jan 18, 2015
# 2310375      justmailtoavi@gmail.com  Mar 30, 2016  Apr 01, 2016
#
#         Content Rating                                     Privacy Policy  \
# 3918          Everyone                                                NaN
# 13758         Everyone  https://smartdailytools.blogspot.com/2020/09/p...
# 25351         Everyone                                                NaN
# 28142         Everyone                                                NaN
# 30962         Everyone  https://www.snatchdreams.net/privacy/tic-tac-toe/
# ...                ...                                                ...
# 2272773       Everyone                  http://mobileappspro.yolasite.com
# 2281376       Everyone  https://docs.google.com/document/d/1Tyi5D3VxZu...
# 2282023       Everyone                                                NaN
# 2299121       Everyone                                                NaN
# 2310375       Everyone                                                NaN
#
#          Ad Supported  In App Purchases  Editors Choice         Scraped Time
# 3918             True             False           False  2021-06-15 20:23:22
# 13758            True             False           False  2021-06-15 20:32:58
# 25351            True             False           False  2021-06-15 20:44:27
# 28142            True             False           False  2021-06-15 20:47:17
# 30962            True             False           False  2021-06-15 20:50:12
# ...               ...               ...             ...                  ...
# 2272773          True             False           False  2021-06-16 12:23:56
# 2281376          True             False           False  2021-06-16 12:31:30
# 2282023         False             False           False  2021-06-16 12:32:05
# 2299121          True             False           False  2021-06-16 12:47:11
# 2310375         False             False           False  2021-06-16 12:57:05
#
# [382 rows x 24 columns]

# %%
df['App Id'].duplicated().any()
# Out:
# False

# %%
df['App Id'].value_counts()
# Out:
# com.ishakwe.gakondo                    1
# com.avai.amp.dewtour                   1
# com.myhomebuy                          1
# com.apocalipseescatologia.app          1
# com.puzzlegame.wordconnect             1
#                                       ..
# id.compro.virtualcompetition           1
# com.fitivity.basketball_point_guard    1
# smartgr.gardenshower.ideas             1
# com.euroland.mobiletools.ae_nbad       1
# com.yyazilim.biliyormusun              1
# Name: App Id, Length: 2312548, dtype: int64

# %% [markdown]
# # (5)	Feature Exploration:

# %% [markdown]
# # 1.Installs column feature

# %%
#Installs column feature
df['Installs'].unique()
# Out:
# array(['10+', '5,000+', '50+', '100+', '1,000+', '500+', '50,000+',
#        '10,000+', '1+', '500,000+', '100,000+', '5+', '10,000,000+',
#        '1,000,000+', '5,000,000+', '0+', '100,000,000+', '50,000,000+',
#        '1,000,000,000+', '500,000,000+', '5,000,000,000+',
#        '10,000,000,000+'], dtype=object)

# %%
#Removing the + symbol from installs column
df['Installs']=df['Installs'].str.split('+').str[0]

# %%
#Replacing the , (comma) symbol from installs column
df['Installs'].replace(',','', inplace=True,regex=True)

# %%
# Converting Installs column into integer type
import numpy as np
df['Installs'] = df['Installs'].astype(np.int64)

# %%
df['Installs'].dtypes
# Out:
# dtype('int64')

# %%
df['Installs'].unique()
# Out:
# array([         10,        5000,          50,         100,        1000,
#                500,       50000,       10000,           1,      500000,
#             100000,           5,    10000000,     1000000,     5000000,
#                  0,   100000000,    50000000,  1000000000,   500000000,
#         5000000000, 10000000000], dtype=int64)

# %% [markdown]
# # 2.Size column feature

# %%
#Size feature, In Size feature the data may be in KB, MB, GB, we will make the size into MB’s size.

# %%
df['Size'].unique()
# Out:
# array(['10M', '2.9M', '3.7M', ..., '405M', '3.2k', '512M'], dtype=object)

# %%
#Removing the'M'
df['Size'] = df['Size'].apply(lambda x: str(x).replace('M','') if 'M' in str(x) else x)

# %%
df['Size'] = df['Size'].apply(lambda x: float(str(x).replace('k', '').replace(',', '')) / 1000 if 'k' in str(x) else x)

# %%
df['Size'] = df['Size'].apply(lambda x: float(str(x).replace('G', '')) * 1000 if 'G' in str(x) else x)

# %%
df['Size'] = df['Size'].apply(lambda x: float(x) if str(x).replace('.', '', 1).isdigit() else x)

# %% [markdown]
# # 3.Free column  feature

# %%
#lets convert boolean values true or false into "Free" and "Paid" so we can easily analyse whether app is free or paid
df['type'] = np.where(df['Free'] == True ,'Free', 'Paid')
df.drop(['Free'],axis=1, inplace = True)

# %% [markdown]
# # 4.Content Rating  feature

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Mature 17+', 'Everyone 10+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
df['Content Rating']=df['Content Rating'].replace("Unrated","Everyone")
df['Content Rating']=df['Content Rating'].replace("Everyone 10+","Teen")
df['Content Rating']=df['Content Rating'].replace("Mature 17+","Adults")
df['Content Rating']=df['Content Rating'].replace("Adults only 18+","Adults")

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Adults'], dtype=object)

# %% [markdown]
# # 5.Rating Count  feature

# %%
df['Rating Count'].unique()
# Out:
# array([0.0000e+00, 6.4000e+01, 5.0000e+00, ..., 8.7553e+04, 7.5960e+04,
#        7.8351e+04])

# %%
#errors='coerce' argument handles any non-numeric values by converting them to NaN

df['Ratingtype'] = 'NoRatingProvided:'
df['Rating Count'] = pd.to_numeric(df['Rating Count'], errors='coerce')
df.loc[(df['Rating Count'] > 0) & (df['Rating Count'] <= 10000.0), 'Ratingtype'] = 'Less than 10k'
df.loc[(df['Rating Count'] > 10000) & (df['Rating Count'] <= 500000.0), 'Ratingtype'] = 'Between 10k and 500k'
df.loc[(df['Rating Count'] > 500000) & (df['Rating Count'] <= 138557570.0), 'Ratingtype'] = 'More than 500k'
df['Ratingtype'].value_counts()
# Out:
# Less than 10k           1192801
# NoRatingProvided:       1082303
# Between 10k and 500k      35779
# More than 500k             1665
# Name: Ratingtype, dtype: int64

# %% [markdown]
# * Questions

# %% [markdown]
# # 1.What are the top 10 Categories that are installed from the Google Play Store?

# %%
Top_10_categories = df.groupby('Category')['Installs'].sum().sort_values(ascending=False).head(10)
print(Top_10_categories)
# Out:
# Category
# Tools                      71440271217
# Communication              43216592414
# Productivity               28313922253
# Photography                18998958963
# Video Players & Editors    18591154109
# Action                     17399855328
# Social                     17165994565
# Entertainment              17108397933
# Casual                     16836783725
# Arcade                     14501230855
# Name: Installs, dtype: int64

# %% [markdown]
# # 2.Which are the Categories that are getting installed the most in top 10 Categories?

# %%
most_installed_category = df.groupby('Category')['Installs'].sum().nlargest(1)
print(most_installed_category)
# Out:
# Category
# Tools    71440271217
# Name: Installs, dtype: int64

# %% [markdown]
# # 3.What is the highest rated Category?

# %%
highest_rated_category = df.groupby('Category')['Rating'].mean().nlargest(1)
print(highest_rated_category )
# Out:
# Category
# Role Playing    3.384498
# Name: Rating, dtype: float64

# %% [markdown]
# # 4.Which Category has the highest Paid and Free apps ?

# %%
paid_apps_category = df[df['type'] == 'Paid'].groupby('Category').size().idxmax()
free_apps_category = df[df['type'] == 'Free'].groupby('Category').size().idxmax()
print(paid_apps_category)
print(free_apps_category)
# Out:
# Education
# Education

# %% [markdown]
# # 5.How does the size of the Application impacts the Installation ?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Grouping the data by 'Size' and calculating the mean of 'Installs'
grouped_data = df.groupby('Size')['Installs'].mean().reset_index()

# Sort the dataframe by 'Size' in ascending order
grouped_data = grouped_data.sort_values('Size')

# Plotting the graph
plt.figure(figsize=(10, 6))
plt.plot(grouped_data['Size'], grouped_data['Installs'], color="green", marker='o', linestyle='-')
plt.xlabel('Application Size')
plt.ylabel('Average Installations')
plt.title('Impact of Application Size on Installations')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 6.What are the Top 5 Paid Apps based With highest ratings and installs ?

# %%
# Filtering the DataFrame for paid apps
paid_apps = df[df['type'] == 'Paid']

# Sorting the DataFrame by ratings and installs in descending order
top_paid_apps = paid_apps.sort_values(by=['Rating', 'Installs'], ascending=False).head(5)

print(top_paid_apps[['App Name', 'Rating', 'Installs']])
# Out:
#                              App Name  Rating  Installs
# 771566                Calculator Plus     5.0    100000
# 507659  Delux Black - Round Icon Pack     5.0     10000
# 572639      FORMA RÉTRO - WIDGET KWGT     5.0     10000
# 673607                         친일인명사전     5.0     10000
# 933192  Himnario IDMJI Coros e Himnos     5.0     10000

# %% [markdown]
# # 7.What are the Top 5 Free Apps based With highest ratings and installs ?

# %%
# Filtering the DataFrame for paid apps
paid_apps = df[df['type'] == 'Free']

# Sorting the DataFrame by ratings and installs in descending order
top_paid_apps = paid_apps.sort_values(by=['Rating', 'Installs'], ascending=False).head(5)

print(top_paid_apps[['App Name', 'Rating', 'Installs']])
# Out:
#                                                App Name  Rating  Installs
# 2035900                                     Photo Frame     5.0  10000000
# 2288188                  Video maker with photo & music     5.0  10000000
# 447796   Kuku FM - Love Stories, Audio Books & Podcasts     5.0   5000000
# 1500940                       Maps Master for Minecraft     5.0   5000000
# 42796       Angry Crocodile Simulator: Crocodile Attack     5.0   1000000

# %%
#converting file to csv
df.to_csv('Google-Playstore.csv',index=False)
